# %% [markdown]
# # Test FilterPipeline
#
# Quick test of the new configuration-based filtering pipeline.

# %%
from dotenv import load_dotenv
from scout.contexts.scraping.scrapers import BoozScraper
from scout.contexts.filtering import FilterPipeline
from pathlib import Path
import os

# %%
load_dotenv()
CONFIG_PATH = Path(os.getenv("CONFIG_PATH"))

# %%
# Initialize scraper and pipeline
bs = BoozScraper()
pipeline = FilterPipeline(CONFIG_PATH / "demo.yaml")

bs.print_cache_summary()

# %%
# Build SQL query from config
query = pipeline.build_sql_query()
print("Generated SQL query:")
print(query)
print()
# Out:
# Generated SQL query:
# SELECT * FROM listings WHERE ( max_salary >= 200000 OR max_salary = 0 ) AND ( date_posted >= '2025-10-07' ) AND (  ( location LIKE '%MD%' )  OR  ( ( location LIKE '%DC%' OR location LIKE '%VA%' ) AND remote = 'Hybrid' )  OR ( remote = 'Yes' ) )

# %%
# Load with SQL filters
df = bs.import_db_as_df(query=query)
print(f"After SQL filtering: {len(df)} jobs")
# Out:
# After SQL filtering: 17 jobs
# /home/sean/SCOUT/scout/contexts/storage/postgres.py:65: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
# Apply all remaining filters from config
df_filtered = pipeline.apply_filters(df, verbose=True)
# Out:
# Starting with 17 jobs
# After keyword filtering: 6 jobs
# After 'Description' red flag filtering: 6 jobs
# After 'Job Title' red flag filtering: 6 jobs
#
# Filtered out 11 jobs (64.7%)

# %%
# Display results
from datetime import datetime

for idx, job in df_filtered.iterrows():
    age_days = (datetime.today() - job["Date Posted"]).days
    print(f"\n{'='*60}")
    print(f"Title: {job['Job Title']}")
    print(f"Salary: ${job['Min Salary']:,} - ${job['Max Salary']:,}")
    print(f"Location: {job['Location']}")
    print(f"Posted: {age_days} days ago")
    print(f"URL: {job['url']}")
# Out:
# ============================================================
# Title: AI Solution Architect
# Salary: $99,000 - $225,000
# Location: McLean,VA,US
# Posted: 3 days ago
# URL: https://careers.boozallen.com/jobs/JobDetail?jobId=116760
#
# ============================================================
# Title: MLOps Engineer, Senior
# Salary: $99,000 - $225,000
# Location: Chantilly,VA,US
# Posted: 6 days ago
# URL: https://careers.boozallen.com/jobs/JobDetail?jobId=116638
#
# ============================================================
# Title: MLOps Engineer, Senior
# Salary: $99,000 - $225,000
# Location: Chantilly,VA,US
# Posted: 6 days ago
# URL: https://careers.boozallen.com/jobs/JobDetail?jobId=116643
#
# ============================================================
# Title: Model and Simulation Engineer, Lead
# Salary: $99,000 - $225,000
# Location: Arlington,VA,US
# Posted: 7 days ago
# URL: https://careers.boozallen.com/jobs/JobDetail?jobId=116608
#
# ============================================================
# Title: Agentic AI &amp; Machine Learning Engineer
# Salary: $99,000 - $225,000
# Location: Bethesda,MD,US
# Posted: 7 days ago
# URL: https://careers.boozallen.com/jobs/JobDetail?jobId=116609
#
# ============================================================
# Title: AI and ML Engineer
# Salary: $99,000 - $225,000
# Location: Ashburn,VA,US
# Posted: 7 days ago
# URL: https://careers.boozallen.com/jobs/JobDetail?jobId=116611

# %%
df_filtered
# Out:
#                                             Job Title Job Number (Public)  \
# 59                               AWS Engineer, Senior            R0227786
# 62         Agentic AI &amp; Machine Learning Engineer            R0227765
# 63                                 AI and ML Engineer            R0227780
# 65                                 AI and ML Engineer            R0227603
# 67                          Product Software Engineer            R0227584
# 69                                Product AI Engineer            R0227588
# 70                         Product DevSecOps Engineer            R0227589
# 88                              AI Solution Architect            R0226854
# 95              Power Platform Integrations Developer            R0227074
# 99  Robotics Engineer and Interdisciplinary Scientist            R0226839
#
#    Job Number (metadata?)                                        Description  \
# 59                 116667  AWS Engineer, Senior\n\n**The Opportunity:**\n...
# 62                 116609  Agentic AI & Machine Learning Engineer\n\n**Th...
# 63                 116611  AI and ML Engineer\n\n**The Opportunity:**\n\n...
# 65                 116506  AI and ML Engineer\n\n**The Opportunity:**\n\n...
# 67                 116485  Product Software Engineer\n\n**The Opportunity...
# 69                 116488  Product AI Engineer\n\n**The Opportunity:**  \...
# 70                 116489  Product DevSecOps Engineer\n\n**The Opportunit...
# 88                 116265  AI Solution Architect\n\n**Key Role:**\n\nDesi...
# 95                 116217  Power Platform Integrations Developer\n\n**The...
# 99                 116024  Robotics Engineer and Interdisciplinary Scient...
#
#    Date Posted          Location Remote Work  \
# 59  2025-10-08     Ashburn,VA,US      Hybrid
# 62  2025-10-07    Bethesda,MD,US      Hybrid
# 63  2025-10-07     Ashburn,VA,US      Hybrid
# 65  2025-10-06     Ashburn,VA,US      Hybrid
# 67  2025-10-03      McLean,VA,US      Hybrid
# 69  2025-10-03      McLean,VA,US      Hybrid
# 70  2025-10-03      McLean,VA,US      Hybrid
# 88  2025-09-29   Arlington,VA,US      Hybrid
# 95  2025-09-26    Bethesda,MD,US      Hybrid
# 99  2025-09-24  Washington,DC,US      Hybrid
#
#                                                   url  Min Salary  Max Salary  \
# 59  https://careers.boozallen.com/jobs/JobDetail?j...       86800      198000
# 62  https://careers.boozallen.com/jobs/JobDetail?j...       99000      225000
# 63  https://careers.boozallen.com/jobs/JobDetail?j...       99000      225000
# 65  https://careers.boozallen.com/jobs/JobDetail?j...       99000      225000
# 67  https://careers.boozallen.com/jobs/JobDetail?j...       86800      198000
# 69  https://careers.boozallen.com/jobs/JobDetail?j...       86800      198000
# 70  https://careers.boozallen.com/jobs/JobDetail?j...       86800      198000
# 88  https://careers.boozallen.com/jobs/JobDetail?j...       99000      225000
# 95  https://careers.boozallen.com/jobs/JobDetail?j...       86800      198000
# 99  https://careers.boozallen.com/jobs/JobDetail?j...       99000      225000
#
#    status last_checked  Description_Good  Job_Title_OK  Clearance Required
# 59   None         None              True          True               False
# 62   None         None              True          True               False
# 63   None         None              True          True               False
# 65   None         None              True          True               False
# 67   None         None              True          True               False
# 69   None         None              True          True               False
# 70   None         None              True          True               False
# 88   None         None              True          True               False
# 95   None         None              True          True               False
# 99   None         None              True          True               False
